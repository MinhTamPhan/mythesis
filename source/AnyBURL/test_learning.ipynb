# %%
from learning import Learning

learner = Learning('WN18')
learner.train()
# Out:
# * indexed 100000 triples
# * set up index for 18 relations, 40504 head entities, and 40551 tail entities
# =====> batch [ACYCLIC 1] 1 (sampled 57 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.79 num of new rule = 21 num of previously rule = 79 num of all batch rules = 100
# =====> stored rules: 21
# =====> batch [CYCLIC 1] 2 (sampled 209 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.868421052631579 num of new rule = 10 num of previously rule = 66 num of all batch rules = 76
# =====> stored rules: 31
# =====> batch [ACYCLIC 1] 3 (sampled 267 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.90625 num of new rule = 9 num of previously rule = 87 num of all batch rules = 96
# =====> stored rules: 40
# =====> batch [CYCLIC 1] 4 (sampled 417 pathes) *****
# ...

# %%
from predict import Predict

predictior = Predict('WN18')
predictior.prediction()
# Out:
# * indexed 100000 triples
# * set up index for 18 relations, 40504 head entities, and 40551 tail entities
# * set up index for 18 relations, 4349 head entities, and 4263 tail entities
# * set up index for 18 relations, 4262 head entities, and 4338 tail entities
# step 0 parsing line 3	2	0.6666666666666666	_member_holonym(X,02601589) <= _hypernym(X,02601344)
# step 1000 parsing line 3	2	0.6666666666666666	_instance_hyponym(10624540,Y) <= _member_meronym(08369920,Y)
# step 2000 parsing line 500	20	0.04	_hypernym(X,01429349) <= _member_holonym(A,X)
# step 3000 parsing line 47916	13	0.00027130812254779195	_part_of(X,Y) <= _synset_domain_topic_of(X,A),_member_of_domain_topic(A,Y)
# step 4000 parsing line 297	5	0.016835016835016835	_instance_hypernym(X,Y) <= _has_part(A,X),_part_of(A,B),_instance_hyponym(Y,B)
# *** read rules 4052 rom file learning_rules/WN18/rule_1000.txt
# * applying rules
# * set up index structure covering rules for 17 different relations
# ...

# %%
from evaluation import Evaluation
eval = Evaluation('WN18')
eval.eval()
# Out:
# * indexed 100000 triples
# * set up index for 18 relations, 40504 head entities, and 40551 tail entities
# * set up index for 18 relations, 4262 head entities, and 4338 tail entities
# * set up index for 18 relations, 4349 head entities, and 4263 tail entities
# hits@1    hits@3    hits@10
# 0.9378	  0.9400    0.9408

# %%
from learning import Learning

learner = Learning('FB15k')
learner.train()
# Out:
# ored rules: 17232
# =====> batch [ACYCLIC 1] 413 (sampled 51914 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.46938775510204084 num of new rule = 52 num of previously rule = 46 num of all batch rules = 98
# =====> stored rules: 17284
# =====> batch [CYCLIC 1] 414 (sampled 52076 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.963855421686747 num of new rule = 3 num of previously rule = 80 num of all batch rules = 83
# =====> stored rules: 17287
# =====> batch [ACYCLIC 1] 415 (sampled 52126 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.5425531914893617 num of new rule = 43 num of previously rule = 51 num of all batch rules = 94
# =====> stored rules: 17330
# =====> batch [CYCLIC 1] 416 (sampled 52323 pathes) *****
# ...

# %%
from predict import Predict

predictior = Predict('FB15k')
predictior.prediction()
# Out:
# # 45000 ) trying to guess the tail/head of /m/01yz0x /award/award_category/nominees./award/award_nomination/award_nominee /m/02xyl
# Elapsed (s) = 1
# * (# 45100 ) trying to guess the tail/head of /m/02k856 /music/instrument/instrumentalists /m/02l_7y
# Elapsed (s) = 1
# * (# 45200 ) trying to guess the tail/head of /m/042zrm /film/film/release_date_s./film/film_regional_release_date/film_release_region /m/0jgd
# Elapsed (s) = 3
# * (# 45300 ) trying to guess the tail/head of /m/05zkcn5 /award/award_category/nominees./award/award_nomination/award_nominee /m/0qf11
# Elapsed (s) = 1
# * (# 45400 ) trying to guess the tail/head of /m/094xh /people/person/profession /m/0nbcg
# Elapsed (s) = 1
# * (# 45500 ) trying to guess the tail/head of /m/099c8n /award/award_category/nominees./award/award_nomination/nominated_for /m/0bnzd
# Elapsed (s) = 1
# * (# 45600 ) trying to guess the tail/head of /m/01d38g /award/award_category/nominees./award/award_nomination/award_nominee /m/01vvycq
# ...

# %%
from evaluation import Evaluation
eval = Evaluation('FB15k')
eval.eval()
# Out:
# * indexed 100000 triples
# * indexed 200000 triples
# * indexed 300000 triples
# * indexed 400000 triples
# * set up index for 1345 relations, 14834 head entities, and 14903 tail entities
# * set up index for 916 relations, 11886 head entities, and 11285 tail entities
# * set up index for 961 relations, 12297 head entities, and 11825 tail entities
# hits@1   hits@3    hits@10
# 0.7913443144690288	0.80844238289516	0.8229926698379916

# %%
from learning import Learning

learner = Learning('FB15k-237')
learner.train()
# Out:
# is batch: 0.532258064516129 num of new rule = 58 num of previously rule = 66 num of all batch rules = 124
# =====> stored rules: 12682
# =====> batch [ACYCLIC 1] 389 (sampled 43863 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.32978723404255317 num of new rule = 63 num of previously rule = 31 num of all batch rules = 94
# =====> stored rules: 12745
# =====> batch [ACYCLIC 1] 390 (sampled 43924 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.4537037037037037 num of new rule = 59 num of previously rule = 49 num of all batch rules = 108
# =====> stored rules: 12804
# =====> batch [ACYCLIC 1] 391 (sampled 43989 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.4830508474576271 num of new rule = 61 num of previously rule = 57 num of all batch rules = 118
# =====> stored rules: 12865
# =====> batch [ACYCLIC 1] 392 (sampled 44050 pathes) *****
# ...

# %%
from predict import Predict

predictior = Predict('FB15k-237')
predictior.prediction()
# Out:
# d
# Elapsed (s) = 1
# * (# 5400 ) trying to guess the tail/head of /m/01jrbb /film/film/release_date_s./film/film_regional_release_date/film_release_region /m/06mkj
# Elapsed (s) = 1
# * (# 5500 ) trying to guess the tail/head of /m/07s6tbm /award/award_nominee/award_nominations./award/award_nomination/award /m/0cjyzs
# Elapsed (s) = 2
# * (# 5600 ) trying to guess the tail/head of /m/04wlh /olympics/olympic_participating_country/athletes./olympics/olympic_athlete_affiliation/olympics /m/06sks6
# Elapsed (s) = 2
# * (# 5700 ) trying to guess the tail/head of /m/01cycq /film/film/other_crew./film/film_crew_gig/film_crew_role /m/09vw2b7
# Elapsed (s) = 1
# * (# 5800 ) trying to guess the tail/head of /m/016ckq /music/record_label/artist /m/012z8_
# Elapsed (s) = 2
# * (# 5900 ) trying to guess the tail/head of /m/0420y /people/person/gender /m/05zppz
# Elapsed (s) = 1
# ...

# %%
from evaluation import Evaluation
eval = Evaluation('FB15k-237')
eval.eval()
# Out:
# * indexed 100000 triples
# * indexed 200000 triples
# * set up index for 237 relations, 13781 head entities, and 13379 tail entities
# * set up index for 223 relations, 7652 head entities, and 5804 tail entities
# * set up index for 224 relations, 8171 head entities, and 6376 tail entities
# hits@1   hits@3    hits@10
# 0.20851656405746116	0.3073878627968338	0.4340369393139842

# %%
from learning import Learning

learner = Learning('WN18RR')
learner.train()
# Out:
# les in this batch: 0.8809523809523809 num of new rule = 10 num of previously rule = 74 num of all batch rules = 84
# =====> stored rules: 3375
# =====> batch [ACYCLIC 1] 418 (sampled 226990 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.945054945054945 num of new rule = 5 num of previously rule = 86 num of all batch rules = 91
# =====> stored rules: 3380
# =====> batch [ACYCLIC 1] 419 (sampled 227048 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.8252427184466019 num of new rule = 18 num of previously rule = 85 num of all batch rules = 103
# =====> stored rules: 3398
# =====> batch [ACYCLIC 1] 420 (sampled 227104 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.8888888888888888 num of new rule = 10 num of previously rule = 80 num of all batch rules = 90
# =====> stored rules: 3408
# =====> batch [ACYCLIC 1] 421 (sampled 227157 pathes) *****
# ...

# %%
from predict import Predict

predictior = Predict('WN18RR')
predictior.prediction()
# Out:
# * set up index for 11 relations, 39610 head entities, and 31881 tail entities
# * set up index for 11 relations, 2958 head entities, and 2619 tail entities
# * set up index for 11 relations, 2851 head entities, and 2575 tail entities
# step 0 parsing line 500	12	0.024	_hypernym(X,08108972) <= _hypernym(A,X)
# step 1000 parsing line 2	2	1.0	_derivationally_related_form(X,01168468) <= _derivationally_related_form(01168468,X)
# step 2000 parsing line 69	18	0.2608695652173913	_member_meronym(11665781,Y) <= _hypernym(Y,11534677)
# step 3000 parsing line 5	3	0.6	_derivationally_related_form(05402091,Y) <= _derivationally_related_form(13454479,Y)
# step 4000 parsing line 2	2	1.0	_synset_domain_topic_of(X,08441203) <= _derivationally_related_form(X,A),_derivationally_related_form(A,06562802)
# *** read rules 4545 rom file learning_rules/WN18RR/rule_1000.txt
# * applying rules
# * set up index structure covering rules for 11 different relations
# * constructed filter set with 93003 triples
# ...

# %%
from evaluation import Evaluation
eval = Evaluation('WN18RR')
eval.eval()
# Out:
# * set up index for 11 relations, 39610 head entities, and 31881 tail entities
# * set up index for 11 relations, 2851 head entities, and 2575 tail entities
# * set up index for 11 relations, 2958 head entities, and 2619 tail entities
# hits@1   hits@3    hits@10
# 0.44224633056796425	0.4883535417996171	0.5422782386726228

# %%
from learning import Learning

learner = Learning('FB15k')
learner.train()
# Out:
# f all batch rules = 31
# =====> stored rules: 10222
# =====> batch [ACYCLIC 1] 858 (sampled 12866 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.2857142857142857 num of new rule = 20 num of previously rule = 8 num of all batch rules = 28
# =====> stored rules: 10242
# =====> batch [ACYCLIC 1] 859 (sampled 12882 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.3333333333333333 num of new rule = 20 num of previously rule = 10 num of all batch rules = 30
# =====> stored rules: 10262
# =====> batch [ACYCLIC 1] 860 (sampled 12897 pathes) *****
# =====> fraction of previously seen rules within useful rules in this batch: 0.3333333333333333 num of new rule = 20 num of previously rule = 10 num of all batch rules = 30
# =====> stored rules: 10282
# =====> batch [ACYCLIC 1] 861 (sampled 12911 pathes) *****
# ...

# %%
from predict import Predict

predictior = Predict('FB15k')
predictior.prediction()
# Out:
# (# 45000 ) trying to guess the tail/head of /m/01yz0x /award/award_category/nominees./award/award_nomination/award_nominee /m/02xyl
# Elapsed (s) = 0
# * (# 45100 ) trying to guess the tail/head of /m/02k856 /music/instrument/instrumentalists /m/02l_7y
# Elapsed (s) = 0
# * (# 45200 ) trying to guess the tail/head of /m/042zrm /film/film/release_date_s./film/film_regional_release_date/film_release_region /m/0jgd
# Elapsed (s) = 1
# * (# 45300 ) trying to guess the tail/head of /m/05zkcn5 /award/award_category/nominees./award/award_nomination/award_nominee /m/0qf11
# Elapsed (s) = 0
# * (# 45400 ) trying to guess the tail/head of /m/094xh /people/person/profession /m/0nbcg
# Elapsed (s) = 0
# * (# 45500 ) trying to guess the tail/head of /m/099c8n /award/award_category/nominees./award/award_nomination/nominated_for /m/0bnzd
# Elapsed (s) = 0
# * (# 45600 ) trying to guess the tail/head of /m/01d38g /award/award_category/nominees./award/award_nomination/award_nominee /m/01vvycq
# ...

# %%
from evaluation import Evaluation
eval = Evaluation('FB15k')
eval.eval()
# Out:
# * indexed 100000 triples
# * indexed 200000 triples
# * indexed 300000 triples
# * indexed 400000 triples
# * set up index for 1345 relations, 14834 head entities, and 14903 tail entities
# * set up index for 916 relations, 11886 head entities, and 11285 tail entities
# * set up index for 961 relations, 12297 head entities, and 11825 tail entities
# hits@1    hits@3    hits@10
# 0.7393	  0.7542    0.7673
